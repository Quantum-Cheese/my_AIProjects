# %%
import matplotlib.pyplot as plt
def plot_behaviers(file_name):
    # plot actions
    file=open(file_name,"r")
    actions=[]
    for line in file.readlines():
        action=line.split(",")
        for a in action:
            actions.append(a)
    lst=[]
    for a in actions:
        b=a.strip('[').strip(']').split(" ")
        lst.append(b)
    action_values=[]
    for l in lst:
        for s in l:
            if (s!='0.' and s!=""):
                    if s!=']':
                        s=s.rstrip("]")
                        action_values.append(float(s))  
    return action_values

# %%
def plot_rewards(file_name):
    f=open(file_name,"r")
    R=[]
    for l in f:
        for r in l.split(','):
            R.append(r)
    Rewards=[]
    for r in R:
        if r!='':
            Rewards.append(float(r))
    return Rewards

# %%
def plot_vel(file_name):
    f=open(file_name,"r")
    R=[]
    for l in f:
        for r in l.split(','):
            R.append(r)
    vels=[]
    for r in R:
        if r!='':
            vels.append(float(r))
    return(vels)

# %%
action_values=plot_behaviers("actions_01.txt")
plt.figure(figsize=(19,8))
plt.plot(action_values)

# %%
plot_rewards("rewards_01.txt")

# %%
action_values=plot_behaviers("actions_02.txt")
plt.figure(figsize=(19,8))
plt.plot(action_values)

# %%
import matplotlib.pyplot as plt
Rewards=plot_rewards("rewards_02.txt")

plt.figure(figsize=(20,8))
plt.plot(Rewards)

# %%
import matplotlib.pyplot as plt
Rewards=plot_rewards("rewards_combined_01.txt")

plt.figure(figsize=(20,8))
plt.plot(Rewards)

# %%
import matplotlib.pyplot as plt
Rewards=plot_rewards("rewards_hover_01.txt")

plt.figure(figsize=(20,8))
plt.plot(Rewards)
